# %% [markdown]
# ## CA High Schools Who Have Met the Benchmark (ERW & Math)

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read Data
df = pd.read_csv('./data/sat_2019_ca.csv')

# %%
df.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# ...

# %%
# Get size (samples & features) of the dataset
size = df.shape
print(size)
# Out:
# (2580, 26)

# %%
df.describe()
# Out:
#                 CDS        CCode        CDCode         SCode       Enroll12  \
# count  2.579000e+03  2579.000000  2.579000e+03  2.579000e+03    2579.000000
# mean   2.915139e+13    28.519581  2.915138e+06  1.544913e+06     748.155487
# std    1.428328e+13    14.258173  1.428327e+06  1.812049e+06   10095.758681
# min    0.000000e+00     0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%    1.964725e+13    19.000000  1.964725e+06  1.025080e+05      63.000000
# 50%    3.066597e+13    30.000000  3.066597e+06  1.377860e+05     171.000000
# 75%    3.777103e+13    37.000000  3.777103e+06  3.037422e+06     462.000000
# max    5.872770e+13    58.000000  5.872769e+06  6.120893e+06  489650.000000
#
#         NumTSTTakr12       Enroll11   NumTSTTakr11  Unnamed: 25
# count    2579.000000    2579.000000    2579.000000          0.0
# mean      264.274137     730.865452     320.473052          NaN
# std      3568.205236    9792.971460    4396.615761          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    2579 non-null   float64
#  1   CCode                  2579 non-null   float64
#  2   CDCode                 2579 non-null   float64
#  3   SCode                  2579 non-null   float64
#  4   RType                  2579 non-null   object
#  5   SName                  1982 non-null   object
#  6   DName                  2521 non-null   object
#  7   CName                  2579 non-null   object
#  8   Enroll12               2579 non-null   float64
#  9   NumTSTTakr12           2579 non-null   float64
#  10  NumERWBenchmark12      2304 non-null   object
#  11  PctERWBenchmark12      2304 non-null   object
#  12  NumMathBenchmark12     2304 non-null   object
#  13  PctMathBenchmark12     2304 non-null   object
# ...

# %%
# Convert non-numeric values to NaN:
df['PctERWBenchmark12'] = pd.to_numeric(df['PctERWBenchmark12'], errors='coerce')
df['NumERWBenchmark12'] = pd.to_numeric(df['NumERWBenchmark12'], errors='coerce')
df['PctMathBenchmark12'] = pd.to_numeric(df['PctMathBenchmark12'], errors='coerce')
df['TotNumBothBenchmark12'] = pd.to_numeric(df['TotNumBothBenchmark12'], errors='coerce')
df['NumMathBenchmark12'] = pd.to_numeric(df['NumMathBenchmark12'], errors='coerce')

# %%
#Check 'TotNumBothBenchmark12' df type

print(df['TotNumBothBenchmark12'].dtype)
# Out:
# float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    2579 non-null   float64
#  1   CCode                  2579 non-null   float64
#  2   CDCode                 2579 non-null   float64
#  3   SCode                  2579 non-null   float64
#  4   RType                  2579 non-null   object
#  5   SName                  1982 non-null   object
#  6   DName                  2521 non-null   object
#  7   CName                  2579 non-null   object
#  8   Enroll12               2579 non-null   float64
#  9   NumTSTTakr12           2579 non-null   float64
#  10  NumERWBenchmark12      1722 non-null   float64
#  11  PctERWBenchmark12      1722 non-null   float64
#  12  NumMathBenchmark12     1722 non-null   float64
#  13  PctMathBenchmark12     1722 non-null   float64
# ...

# %%
# Select the columns that you want to measure
schools = df[['SName', 'PctBothBenchmark12']]

# %%
schools
# Out:
#                         SName PctBothBenchmark12
# 0     Colusa Alternative Home                NaN
# 1             Maxwell Sr High                  *
# 2         Belmont Senior High              13.73
# 3     Canoga Park Senior High              15.93
# 4        Whitman Continuation                  *
# ...                       ...                ...
# 2575                      NaN              87.30
# 2576                      NaN              50.28
# 2577                      NaN              38.92
# 2578                      NaN              55.32
# 2579                      NaN                NaN
#
# [2580 rows x 2 columns]

# %%
# Get the Highest Percentages
schools_high_bench = df[['SName', 'PctBothBenchmark12']]
schools_high_bench = schools.sort_values('PctBothBenchmark12', ascending=False)

# %%
schools_high_bench
# Out:
#                                               SName PctBothBenchmark12
# 1747                        Whitney (Gretchen) High              98.75
# 364                                Monta Vista High              96.95
# 144                           Mission San Jose High              95.30
# 1736  California Academy of Mathematics and Science              95.10
# 1100                                  Lynbrook High              94.64
# ...                                             ...                ...
# 2540                                            NaN                NaN
# 2561                                            NaN                NaN
# 2572                                            NaN                NaN
# 2573                                            NaN                NaN
# 2579                                            NaN                NaN
#
# [2580 rows x 2 columns]

# %%
schools_high_bench['PctBothBenchmark12'] = schools_high_bench['PctBothBenchmark12'].astype(str)

# %%
schools_high_bench
# Out:
#                                               SName PctBothBenchmark12
# 1747                        Whitney (Gretchen) High              98.75
# 364                                Monta Vista High              96.95
# 144                           Mission San Jose High              95.30
# 1736  California Academy of Mathematics and Science              95.10
# 1100                                  Lynbrook High              94.64
# ...                                             ...                ...
# 2540                                            NaN                nan
# 2561                                            NaN                nan
# 2572                                            NaN                nan
# 2573                                            NaN                nan
# 2579                                            NaN                nan
#
# [2580 rows x 2 columns]

# %%
# Remove rows containing NaN values
schools_high_bench = schools_high_bench.dropna()
schools_high_bench
# Out:
#                                               SName PctBothBenchmark12
# 1747                        Whitney (Gretchen) High              98.75
# 364                                Monta Vista High              96.95
# 144                           Mission San Jose High              95.30
# 1736  California Academy of Mathematics and Science              95.10
# 1100                                  Lynbrook High              94.64
# ...                                             ...                ...
# 1961                          Ronald Reagan Academy                nan
# 1962                                   Shandon High                nan
# 1963                              Independence High                nan
# 1969                          Golden Valley Charter                nan
# 1971                 Olive Grove Charter - Buellton                nan
#
# [1982 rows x 2 columns]

# %%
schools_high_bench['PctBothBenchmark12'] = schools_high_bench['PctBothBenchmark12'].replace('*', np.nan).astype(float)
schools_high_bench
# Out:
#                                               SName  PctBothBenchmark12
# 272                  William & Marian Ghidotti High              100.00
# 1747                        Whitney (Gretchen) High               98.75
# 364                                Monta Vista High               96.95
# 144                           Mission San Jose High               95.30
# 1736  California Academy of Mathematics and Science               95.10
# ...                                             ...                 ...
# 1961                          Ronald Reagan Academy                 NaN
# 1962                                   Shandon High                 NaN
# 1963                              Independence High                 NaN
# 1969                          Golden Valley Charter                 NaN
# 1971                 Olive Grove Charter - Buellton                 NaN
#
# [1982 rows x 2 columns]

# %%
# Replace '*' values with NaN
schools_high_bench['PctBothBenchmark12'] = schools_high_bench['PctBothBenchmark12'].replace('*', np.nan)

# Convert PctBothBenchmark12 to float data type
schools_high_bench['PctBothBenchmark12'] = schools_high_bench['PctBothBenchmark12'].astype(float)

# Sort data by PctBothBenchmark12 in descending order
schools_high_bench = schools_high_bench.sort_values('PctBothBenchmark12', ascending=False)

# Select the top 5 schools with the highest PctBothBenchmark12 values
top_5_schools = schools_high_bench.head(5)

# Print the top 5 schools
print(top_5_schools)
# Out:
#                                               SName  PctBothBenchmark12
# 272                  William & Marian Ghidotti High              100.00
# 1747                        Whitney (Gretchen) High               98.75
# 364                                Monta Vista High               96.95
# 144                           Mission San Jose High               95.30
# 1736  California Academy of Mathematics and Science               95.10

# %%
# Set color scheme for California
ca_color = ['red', 'orange', 'green','blue', 'purple']

# Filter the top 5 high schools
top_schools = schools_high_bench.nlargest(5, 'PctBothBenchmark12')

# Create a bar chart for the top 5 high schools
fig, ax = plt.subplots(figsize=(10, 7))
ax.bar(top_schools['SName'], top_schools['PctBothBenchmark12'], color=ca_color)

# Set chart title and axis labels
ax.set_title('Top 5 CA High Schools with High Benchmark Scores', fontsize=16)
ax.set_xlabel('School Name', fontsize=25, loc= 'center')
ax.set_ylabel('% of Students Meeting Both Benchmarks', fontsize=12)

plt.xticks(rotation=35, ha='right', size=12, va='top')

# Set y-axis limit to 100%
ax.set_ylim([0, 100])

# Show the plot
plt.tight_layout()
plt.savefig('./charts/Top_CA_high')

# %% [markdown]
#  ## CA High Schools That Did Not Meet The Benchmark (ERW )and Math.

# %%
# Get the Lowest Percentages
schools_low_bench = df[['SName', 'PctBothBenchmark12']]
schools_low_bench = schools.sort_values('PctBothBenchmark12', ascending=True)

# %%
schools_low_bench
# Out:
#                                                   SName  PctBothBenchmark12
# 1136                               Elwood J. Keema High                 0.0
# 420   Augustus F. Hawkins High B Community Health Ad...                 0.0
# 1905                               Lorin Griset Academy                 0.0
# 1863                                March Mountain High                 0.0
# 263                                     Sun Valley High                 0.0
# ...                                                 ...                 ...
# 2570                                                NaN                 NaN
# 2571                                                NaN                 NaN
# 2572                                                NaN                 NaN
# 2573                                                NaN                 NaN
# 2579                                                NaN                 NaN
#
# [2580 rows x 2 columns]

# %% [markdown]
#  Unlike the top 5 flourshing High Schools in CA "59.9% of students are economically disadvantaged" based on USNews.com in the lowest scored Benchmark schools, which presents only one factor to this data.
# Further studies can determine:
# - Better resources for improved scores.
# - Best educational practices for High school students and the community.
